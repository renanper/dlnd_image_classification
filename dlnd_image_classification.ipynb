# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 4000
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %% [markdown]
# Tip:
# Min-Max Scaling:
# $
# X'=a+{\frac {\left(X-X_{\min }\right)\left(b-a\right)}{X_{\max }-X_{\min }}}
# $

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    a = 0
    b = 1
    x_min = 0
    x_max = 255
    return a + (x-x_min)*(b-a)/(x_max-x_min)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    hot_encoded_labels = []
    for label in x:
        hot_encode = np.zeros(10)
        hot_encode[label] = 1
        hot_encoded_labels.append(hot_encode)
    return np.array(hot_encoded_labels)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    #hint: as per lesson Convolutional Networks. 31:
        ## `tf.nn.conv2d` requires the input be 4D (batch_size, height, width, depth)
    batch_size = None
    height = image_shape[0]
    width = image_shape[1]
    depth = image_shape[2]    
    return tf.placeholder(tf.float32, shape=(batch_size, height, width, depth),name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    
    # The shape of the filter weight is (height, width, input_depth, output_depth)
    # The shape of the filter bias is (output_depth,)
    
    filter_weight = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],conv_num_outputs],mean = 0.0,stddev=0.1))
    filter_bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    #hint: as per lesson Convolutional Networks part 14:
        #Set the stride for each dimension (batch_size, height, width, depth)
        # We are generally (WHY?) always going to set the stride for batch and input_channels 
        # (i.e. the first and fourth element in the strides array) to be 1. 
    strides = [1, conv_strides[0], conv_strides[1], 1]
    padding = 'SAME'
    conv_layer = tf.nn.conv2d(x_tensor, filter_weight, strides, padding) + filter_bias
    conv_layer = tf.nn.relu(conv_layer)
    
    #hint: as per lesson Convolutional Networks part 19:
        #The ksize and strides parameters are structured as 4-element lists, 
        #with each element corresponding to a dimension of the input tensor ([batch, height, width, channels]). 
        #For both ksize and strides, the batch and channel dimensions are typically set to 1.
    k_size_max_pool = [1, pool_ksize[0], pool_ksize[1], 1]
    strides_max_pool = [1, pool_strides[0], pool_strides[1], 1]
    
    conv_layer = tf.nn.max_pool(
    conv_layer,
    k_size_max_pool,
    strides_max_pool,
    padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    return tf.reshape(x_tensor, [tf.shape(x_tensor)[0], x_tensor.get_shape().as_list()[1] * x_tensor.get_shape().as_list()[2] * x_tensor.get_shape().as_list()[3] ])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # A fully connected layer is a simple neuron network layer (matrix multiplication)
    weights = tf.Variable(tf.truncated_normal((x_tensor.get_shape().as_list()[1], num_outputs),mean = 0.0,stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), bias))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights = tf.Variable(tf.truncated_normal((x_tensor.get_shape().as_list()[1], num_outputs),mean = 0.0,stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weights), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    net = conv2d_maxpool(x, 64, (3,3), (1,1), (2,2), (2,2))
    net = tf.nn.dropout(net, keep_prob)
#     net = conv2d_maxpool(net, 64, (3,3), (1,1), (2,2), (2,2))
#     net = conv2d_maxpool(net, 64, (3,3), (1,1), (2,2), (2,2))
#     net = tf.nn.dropout(net, keep_prob)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    net = flatten(net)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    net = fully_conn(net, 1032)
    net = tf.nn.dropout(net, keep_prob)
#     net = fully_conn(net, 4096)
#     net = tf.nn.dropout(net, keep_prob)
#     net = fully_conn(net, 1000)

    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    net = output(net, 10)
    
    return net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    l = session.run(
                cost,
                feed_dict={x: feature_batch, y: label_batch, keep_prob:1.0})
    
    validation_accuracy = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0})
    print('Loss at {}'.format(l))
    print('Validation accuracy at {}'.format(validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 128
keep_probability = 1.0

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss at 1.7843799591064453
# Validation accuracy at 0.3765999674797058
# Epoch  2, CIFAR-10 Batch 1:  Loss at 1.2263978719711304
# Validation accuracy at 0.4883999824523926
# Epoch  3, CIFAR-10 Batch 1:  Loss at 0.8495290875434875
# Validation accuracy at 0.5269999504089355
# Epoch  4, CIFAR-10 Batch 1:  Loss at 0.641360342502594
# Validation accuracy at 0.5409999489784241
# Epoch  5, CIFAR-10 Batch 1:  Loss at 0.5129088163375854
# Validation accuracy at 0.5399999618530273
# Epoch  6, CIFAR-10 Batch 1:  Loss at 0.3743721842765808
# Validation accuracy at 0.5327999591827393
# Epoch  7, CIFAR-10 Batch 1:  Loss at 0.22734883427619934
# Validation accuracy at 0.5275999307632446
# Epoch  8, CIFAR-10 Batch 1:  Loss at 0.20846784114837646
# Validation accuracy at 0.5299999117851257
# Epoch  9, CIFAR-10 Batch 1:  Loss at 0.14863771200180054
# Validation accuracy at 0.5123999714851379
# Epoch 10, CIFAR-10 Batch 1:  Loss at 0.10555070638656616
# Validation accuracy at 0.5269999504089355
# Epoch 11, CIFAR-10 Batch 1:  Loss at 0.09304454922676086
# Validation accuracy at 0.5341999530792236
# Epoch 12, CIFAR-10 Batch 1:  Loss at 0.08008119463920593
# Validation accuracy at 0.5419999361038208
# Epoch 13, CIFAR-10 Batch 1:  Loss at 0.054045356810092926
# Validation accuracy at 0.5413999557495117
# Epoch 14, CIFAR-10 Batch 1:  Loss at 0.046286337077617645
# Validation accuracy at 0.5583999752998352
# Epoch 15, CIFAR-10 Batch 1:  Loss at 0.04565151035785675
# Validation accuracy at 0.5455999374389648
# Epoch 16, CIFAR-10 Batch 1:  Loss at 0.02798578515648842
# Validation accuracy at 0.5519999265670776
# Epoch 17, CIFAR-10 Batch 1:  Loss at 0.03404582291841507
# Validation accuracy at 0.5503999590873718
# Epoch 18, CIFAR-10 Batch 1:  Loss at 0.02317078784108162
# Validation accuracy at 0.545199990272522
# Epoch 19, CIFAR-10 Batch 1:  Loss at 0.01428880076855421
# Validation accuracy at 0.544999897480011
# Epoch 20, CIFAR-10 Batch 1:  Loss at 0.02103712037205696
# Validation accuracy at 0.5405999422073364
# Epoch 21, CIFAR-10 Batch 1:  Loss at 0.016130823642015457
# Validation accuracy at 0.5353999733924866
# Epoch 22, CIFAR-10 Batch 1:  Loss at 0.008992890827357769
# Validation accuracy at 0.5433998703956604
# Epoch 23, CIFAR-10 Batch 1:  Loss at 0.01047589536756277
# Validation accuracy at 0.5559999346733093
# Epoch 24, CIFAR-10 Batch 1:  Loss at 0.005606842692941427
# Validation accuracy at 0.5661998987197876
# Epoch 25, CIFAR-10 Batch 1:  Loss at 0.003591381013393402
# Validation accuracy at 0.5673999190330505
# Epoch 26, CIFAR-10 Batch 1:  Loss at 0.0031602373346686363
# Validation accuracy at 0.560999870300293
# Epoch 27, CIFAR-10 Batch 1:  Loss at 0.002175607020035386
# Validation accuracy at 0.5669999122619629
# Epoch 28, CIFAR-10 Batch 1:  Loss at 0.001965317642316222
# Validation accuracy at 0.5685999393463135
# Epoch 29, CIFAR-10 Batch 1:  Loss at 0.0013703685253858566
# Validation accuracy at 0.5707998871803284
# Epoch 30, CIFAR-10 Batch 1:  Loss at 0.001036740723066032
# Validation accuracy at 0.5733999013900757
# Epoch 31, CIFAR-10 Batch 1:  Loss at 0.0008886349387466908
# Validation accuracy at 0.5725998878479004
# Epoch 32, CIFAR-10 Batch 1:  Loss at 0.0007998952060006559
# Validation accuracy at 0.5743998885154724
# Epoch 33, CIFAR-10 Batch 1:  Loss at 0.0007942912634462118
# Validation accuracy at 0.5703999400138855
# Epoch 34, CIFAR-10 Batch 1:  Loss at 0.000812834594398737
# Validation accuracy at 0.5697999000549316
# Epoch 35, CIFAR-10 Batch 1:  Loss at 0.0008237634319812059
# Validation accuracy at 0.5703999400138855
# Epoch 36, CIFAR-10 Batch 1:  Loss at 0.0008218076545745134
# Validation accuracy at 0.5693999528884888
# Epoch 37, CIFAR-10 Batch 1:  Loss at 0.0007667159661650658
# Validation accuracy at 0.5673999190330505
# Epoch 38, CIFAR-10 Batch 1:  Loss at 0.0007107112323865294
# Validation accuracy at 0.5663999319076538
# Epoch 39, CIFAR-10 Batch 1:  Loss at 0.000649632653221488
# Validation accuracy at 0.5663999319076538
# Epoch 40, CIFAR-10 Batch 1:  Loss at 0.00058251793961972
# Validation accuracy at 0.5667999386787415
# Epoch 41, CIFAR-10 Batch 1:  Loss at 0.0005258480668999255
# Validation accuracy at 0.568399965763092
# Epoch 42, CIFAR-10 Batch 1:  Loss at 0.0004875555168837309
# Validation accuracy at 0.5683999061584473
# Epoch 43, CIFAR-10 Batch 1:  Loss at 0.00042632693657651544
# Validation accuracy at 0.5705999135971069
# Epoch 44, CIFAR-10 Batch 1:  Loss at 0.00038722524186596274
# Validation accuracy at 0.5705999135971069
# Epoch 45, CIFAR-10 Batch 1:  Loss at 0.0003325633588247001
# Validation accuracy at 0.5729999542236328
# Epoch 46, CIFAR-10 Batch 1:  Loss at 0.000318115868140012
# Validation accuracy at 0.5743999481201172
# Epoch 47, CIFAR-10 Batch 1:  Loss at 0.0002846393617801368
# Validation accuracy at 0.5757999420166016
# Epoch 48, CIFAR-10 Batch 1:  Loss at 0.0002806115080602467
# Validation accuracy at 0.5749999284744263
# Epoch 49, CIFAR-10 Batch 1:  Loss at 0.0002558934211265296
# Validation accuracy at 0.5735999345779419
# Epoch 50, CIFAR-10 Batch 1:  Loss at 0.00023601384600624442
# Validation accuracy at 0.574199914932251

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# save_model_path = './image_classification'
save_model_path = '/dev/tf_models/image_classification'
print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss at 1.9247610569000244
# Validation accuracy at 0.37379997968673706
# Epoch  1, CIFAR-10 Batch 2:  Loss at 1.4347095489501953
# Validation accuracy at 0.46859994530677795
# Epoch  1, CIFAR-10 Batch 3:  Loss at 1.2838637828826904
# Validation accuracy at 0.5087999105453491
# Epoch  1, CIFAR-10 Batch 4:  Loss at 1.0787984132766724
# Validation accuracy at 0.532599925994873
# Epoch  1, CIFAR-10 Batch 5:  Loss at 1.1489543914794922
# Validation accuracy at 0.5681999921798706
# Epoch  2, CIFAR-10 Batch 1:  Loss at 1.1589219570159912
# Validation accuracy at 0.5765998959541321
# Epoch  2, CIFAR-10 Batch 2:  Loss at 0.8306834697723389
# Validation accuracy at 0.5887999534606934
# Epoch  2, CIFAR-10 Batch 3:  Loss at 0.6870026588439941
# Validation accuracy at 0.5911999344825745
# Epoch  2, CIFAR-10 Batch 4:  Loss at 0.7041090130805969
# Validation accuracy at 0.6075999140739441
# Epoch  2, CIFAR-10 Batch 5:  Loss at 0.6811115741729736
# Validation accuracy at 0.6165998578071594
# Epoch  3, CIFAR-10 Batch 1:  Loss at 0.7719050645828247
# Validation accuracy at 0.606999933719635
# Epoch  3, CIFAR-10 Batch 2:  Loss at 0.4998462498188019
# Validation accuracy at 0.6205999255180359
# Epoch  3, CIFAR-10 Batch 3:  Loss at 0.36484959721565247
# Validation accuracy at 0.626599907875061
# Epoch  3, CIFAR-10 Batch 4:  Loss at 0.45305776596069336
# Validation accuracy at 0.6329998970031738
# Epoch  3, CIFAR-10 Batch 5:  Loss at 0.41747280955314636
# Validation accuracy at 0.6293998956680298
# Epoch  4, CIFAR-10 Batch 1:  Loss at 0.5443329811096191
# Validation accuracy at 0.6189998984336853
# Epoch  4, CIFAR-10 Batch 2:  Loss at 0.3198281228542328
# Validation accuracy at 0.6347998976707458
# Epoch  4, CIFAR-10 Batch 3:  Loss at 0.20296180248260498
# Validation accuracy at 0.6329998970031738
# Epoch  4, CIFAR-10 Batch 4:  Loss at 0.2818765342235565
# Validation accuracy at 0.6365998983383179
# Epoch  4, CIFAR-10 Batch 5:  Loss at 0.2840474247932434
# Validation accuracy at 0.6241998672485352
# Epoch  5, CIFAR-10 Batch 1:  Loss at 0.38901594281196594
# Validation accuracy at 0.624799907207489
# Epoch  5, CIFAR-10 Batch 2:  Loss at 0.26840445399284363
# Validation accuracy at 0.6075999140739441
# Epoch  5, CIFAR-10 Batch 3:  Loss at 0.1439141482114792
# Validation accuracy at 0.6091999411582947
# Epoch  5, CIFAR-10 Batch 4:  Loss at 0.20627212524414062
# Validation accuracy at 0.6223999261856079
# Epoch  5, CIFAR-10 Batch 5:  Loss at 0.19080105423927307
# Validation accuracy at 0.6261999011039734
# Epoch  6, CIFAR-10 Batch 1:  Loss at 0.21131275594234467
# Validation accuracy at 0.6273999214172363
# Epoch  6, CIFAR-10 Batch 2:  Loss at 0.10446476936340332
# Validation accuracy at 0.6347998976707458
# Epoch  6, CIFAR-10 Batch 3:  Loss at 0.10750862210988998
# Validation accuracy at 0.644399881362915
# Epoch  6, CIFAR-10 Batch 4:  Loss at 0.11684505641460419
# Validation accuracy at 0.6051998734474182
# Epoch  6, CIFAR-10 Batch 5:  Loss at 0.13498170673847198
# Validation accuracy at 0.6063998937606812
# Epoch  7, CIFAR-10 Batch 1:  Loss at 0.11863982677459717
# Validation accuracy at 0.6419998407363892
# Epoch  7, CIFAR-10 Batch 2:  Loss at 0.07607270777225494
# Validation accuracy at 0.6339998841285706
# Epoch  7, CIFAR-10 Batch 3:  Loss at 0.09676861763000488
# Validation accuracy at 0.6415998935699463
# Epoch  7, CIFAR-10 Batch 4:  Loss at 0.08506681025028229
# Validation accuracy at 0.6063998937606812
# Epoch  7, CIFAR-10 Batch 5:  Loss at 0.08951567113399506
# Validation accuracy at 0.6235999464988708
# Epoch  8, CIFAR-10 Batch 1:  Loss at 0.0860053151845932
# Validation accuracy at 0.6347998976707458
# Epoch  8, CIFAR-10 Batch 2:  Loss at 0.09088797122240067
# Validation accuracy at 0.6159999370574951
# Epoch  8, CIFAR-10 Batch 3:  Loss at 0.044416047632694244
# Validation accuracy at 0.6173999309539795
# Epoch  8, CIFAR-10 Batch 4:  Loss at 0.053724855184555054
# Validation accuracy at 0.656999945640564
# Epoch  8, CIFAR-10 Batch 5:  Loss at 0.04707061126828194
# Validation accuracy at 0.6165999174118042
# Epoch  9, CIFAR-10 Batch 1:  Loss at 0.07654473185539246
# Validation accuracy at 0.6263998746871948
# Epoch  9, CIFAR-10 Batch 2:  Loss at 0.03730977699160576
# Validation accuracy at 0.593799889087677
# Epoch  9, CIFAR-10 Batch 3:  Loss at 0.03445998951792717
# Validation accuracy at 0.631399929523468
# Epoch  9, CIFAR-10 Batch 4:  Loss at 0.0349724218249321
# Validation accuracy at 0.6351999044418335
# Epoch  9, CIFAR-10 Batch 5:  Loss at 0.030516913160681725
# Validation accuracy at 0.632599949836731
# Epoch 10, CIFAR-10 Batch 1:  Loss at 0.053497523069381714
# Validation accuracy at 0.6269999146461487
# Epoch 10, CIFAR-10 Batch 2:  Loss at 0.021189842373132706
# Validation accuracy at 0.6269999146461487
# Epoch 10, CIFAR-10 Batch 3:  Loss at 0.026751047000288963
# Validation accuracy at 0.6289998888969421
# Epoch 10, CIFAR-10 Batch 4:  Loss at 0.04009243845939636
# Validation accuracy at 0.6231999397277832
# Epoch 10, CIFAR-10 Batch 5:  Loss at 0.02726031094789505
# Validation accuracy at 0.6341999173164368
# Epoch 11, CIFAR-10 Batch 1:  Loss at 0.02143879421055317
# Validation accuracy at 0.6373999118804932
# Epoch 11, CIFAR-10 Batch 2:  Loss at 0.018703322857618332
# Validation accuracy at 0.6349998712539673
# Epoch 11, CIFAR-10 Batch 3:  Loss at 0.019302522763609886
# Validation accuracy at 0.6269998550415039
# Epoch 11, CIFAR-10 Batch 4:  Loss at 0.04188515990972519
# Validation accuracy at 0.6185998916625977
# Epoch 11, CIFAR-10 Batch 5:  Loss at 0.02076352760195732
# Validation accuracy at 0.6429998874664307
# Epoch 12, CIFAR-10 Batch 1:  Loss at 0.02965577132999897
# Validation accuracy at 0.6433998942375183
# Epoch 12, CIFAR-10 Batch 2:  Loss at 0.013340050354599953
# Validation accuracy at 0.6463998556137085
# Epoch 12, CIFAR-10 Batch 3:  Loss at 0.011150706559419632
# Validation accuracy at 0.6131998896598816
# Epoch 12, CIFAR-10 Batch 4:  Loss at 0.028102202340960503
# Validation accuracy at 0.6355998516082764
# Epoch 12, CIFAR-10 Batch 5:  Loss at 0.023639800027012825
# Validation accuracy at 0.621199905872345
# Epoch 13, CIFAR-10 Batch 1:  Loss at 0.028042670339345932
# Validation accuracy at 0.6287997961044312
# Epoch 13, CIFAR-10 Batch 2:  Loss at 0.013280941173434258
# Validation accuracy at 0.6515998840332031
# Epoch 13, CIFAR-10 Batch 3:  Loss at 0.007134291809052229
# Validation accuracy at 0.5897999405860901
# Epoch 13, CIFAR-10 Batch 4:  Loss at 0.013813959434628487
# Validation accuracy at 0.6449999213218689
# Epoch 13, CIFAR-10 Batch 5:  Loss at 0.01285022683441639
# Validation accuracy at 0.6163999438285828
# Epoch 14, CIFAR-10 Batch 1:  Loss at 0.014849655330181122
# Validation accuracy at 0.6319999098777771
# Epoch 14, CIFAR-10 Batch 2:  Loss at 0.009715909138321877
# Validation accuracy at 0.6307998895645142
# Epoch 14, CIFAR-10 Batch 3:  Loss at 0.006146278232336044
# Validation accuracy at 0.6189998984336853
# Epoch 14, CIFAR-10 Batch 4:  Loss at 0.016956167295575142
# Validation accuracy at 0.61819988489151
# Epoch 14, CIFAR-10 Batch 5:  Loss at 0.004354406613856554
# Validation accuracy at 0.6613999009132385
# Epoch 15, CIFAR-10 Batch 1:  Loss at 0.005202483851462603
# Validation accuracy at 0.6405999064445496
# Epoch 15, CIFAR-10 Batch 2:  Loss at 0.003595876507461071
# Validation accuracy at 0.6469998955726624
# Epoch 15, CIFAR-10 Batch 3:  Loss at 0.003241259604692459
# Validation accuracy at 0.6379998922348022
# Epoch 15, CIFAR-10 Batch 4:  Loss at 0.01967559941112995
# Validation accuracy at 0.6141998767852783
# Epoch 15, CIFAR-10 Batch 5:  Loss at 0.006881738547235727
# Validation accuracy at 0.6541998386383057
# Epoch 16, CIFAR-10 Batch 1:  Loss at 0.004450691863894463
# Validation accuracy at 0.6441999077796936
# Epoch 16, CIFAR-10 Batch 2:  Loss at 0.0028740919660776854
# Validation accuracy at 0.6467999219894409
# Epoch 16, CIFAR-10 Batch 3:  Loss at 0.0028662842232733965
# Validation accuracy at 0.6507999300956726
# Epoch 16, CIFAR-10 Batch 4:  Loss at 0.008990379050374031
# Validation accuracy at 0.622999906539917
# Epoch 16, CIFAR-10 Batch 5:  Loss at 0.006269893143326044
# Validation accuracy at 0.6441999077796936
# Epoch 17, CIFAR-10 Batch 1:  Loss at 0.007450124714523554
# Validation accuracy at 0.6465998888015747
# Epoch 17, CIFAR-10 Batch 2:  Loss at 0.0062277051620185375
# Validation accuracy at 0.6195998787879944
# Epoch 17, CIFAR-10 Batch 3:  Loss at 0.003816701006144285
# Validation accuracy at 0.6399999260902405
# Epoch 17, CIFAR-10 Batch 4:  Loss at 0.002843700349330902
# Validation accuracy at 0.6547998785972595
# Epoch 17, CIFAR-10 Batch 5:  Loss at 0.0020702737383544445
# Validation accuracy at 0.6583998203277588
# Epoch 18, CIFAR-10 Batch 1:  Loss at 0.004916064906865358
# Validation accuracy at 0.6379998922348022
# Epoch 18, CIFAR-10 Batch 2:  Loss at 0.006393866613507271
# Validation accuracy at 0.6261999011039734
# Epoch 18, CIFAR-10 Batch 3:  Loss at 0.0043582613579928875
# Validation accuracy at 0.643799901008606
# Epoch 18, CIFAR-10 Batch 4:  Loss at 0.003151652868837118
# Validation accuracy at 0.6495998501777649
# Epoch 18, CIFAR-10 Batch 5:  Loss at 0.003923262469470501
# Validation accuracy at 0.6241998672485352
# Epoch 19, CIFAR-10 Batch 1:  Loss at 0.003576521296054125
# Validation accuracy at 0.6405999064445496
# Epoch 19, CIFAR-10 Batch 2:  Loss at 0.003778204321861267
# Validation accuracy at 0.6385999321937561
# Epoch 19, CIFAR-10 Batch 3:  Loss at 0.0010421441402286291
# Validation accuracy at 0.6487998962402344
# Epoch 19, CIFAR-10 Batch 4:  Loss at 0.00477832555770874
# Validation accuracy at 0.6453998684883118
# Epoch 19, CIFAR-10 Batch 5:  Loss at 0.004670992493629456
# Validation accuracy at 0.6255999207496643
# Epoch 20, CIFAR-10 Batch 1:  Loss at 0.0025286353193223476
# Validation accuracy at 0.6435999274253845
# Epoch 20, CIFAR-10 Batch 2:  Loss at 0.001601777970790863
# Validation accuracy at 0.6487998962402344
# Epoch 20, CIFAR-10 Batch 3:  Loss at 0.0010409316746518016
# Validation accuracy at 0.6409997940063477
# Epoch 20, CIFAR-10 Batch 4:  Loss at 0.0033804576378315687
# Validation accuracy at 0.6361998915672302
# Epoch 20, CIFAR-10 Batch 5:  Loss at 0.0018228177214041352
# Validation accuracy at 0.6413998603820801
# Epoch 21, CIFAR-10 Batch 1:  Loss at 0.004951223731040955
# Validation accuracy at 0.6349999308586121
# Epoch 21, CIFAR-10 Batch 2:  Loss at 0.0009906092891469598
# Validation accuracy at 0.640799880027771
# Epoch 21, CIFAR-10 Batch 3:  Loss at 0.0031999112106859684
# Validation accuracy at 0.63319993019104
# Epoch 21, CIFAR-10 Batch 4:  Loss at 0.0027426916640251875
# Validation accuracy at 0.6261999607086182
# Epoch 21, CIFAR-10 Batch 5:  Loss at 0.0023796537425369024
# Validation accuracy at 0.6435999274253845
# Epoch 22, CIFAR-10 Batch 1:  Loss at 0.004045449197292328
# Validation accuracy at 0.6201999187469482
# Epoch 22, CIFAR-10 Batch 2:  Loss at 0.00196766946464777
# Validation accuracy at 0.6449999213218689
# Epoch 22, CIFAR-10 Batch 3:  Loss at 0.0014577246038243175
# Validation accuracy at 0.6333999037742615
# Epoch 22, CIFAR-10 Batch 4:  Loss at 0.0027375947684049606
# Validation accuracy at 0.6355998516082764
# Epoch 22, CIFAR-10 Batch 5:  Loss at 0.002106172265484929
# Validation accuracy at 0.6429999470710754
# Epoch 23, CIFAR-10 Batch 1:  Loss at 0.0015399239491671324
# Validation accuracy at 0.6285998821258545
# Epoch 23, CIFAR-10 Batch 2:  Loss at 0.00260360399261117
# Validation accuracy at 0.6519998908042908
# Epoch 23, CIFAR-10 Batch 3:  Loss at 0.001990645658224821
# Validation accuracy at 0.621799886226654
# Epoch 23, CIFAR-10 Batch 4:  Loss at 0.0012700730003416538
# Validation accuracy at 0.6465999484062195
# Epoch 23, CIFAR-10 Batch 5:  Loss at 0.0029106740839779377
# Validation accuracy at 0.6439999341964722
# Epoch 24, CIFAR-10 Batch 1:  Loss at 0.0026401071809232235
# Validation accuracy at 0.6185998916625977
# Epoch 24, CIFAR-10 Batch 2:  Loss at 0.004450480453670025
# Validation accuracy at 0.6493998765945435
# Epoch 24, CIFAR-10 Batch 3:  Loss at 0.003073561703786254
# Validation accuracy at 0.6031998991966248
# Epoch 24, CIFAR-10 Batch 4:  Loss at 0.001638186746276915
# Validation accuracy at 0.6471999287605286
# Epoch 24, CIFAR-10 Batch 5:  Loss at 0.0013097439659759402
# Validation accuracy at 0.6375998854637146
# Epoch 25, CIFAR-10 Batch 1:  Loss at 0.003578418865799904
# Validation accuracy at 0.6223998665809631
# Epoch 25, CIFAR-10 Batch 2:  Loss at 0.0016466900706291199
# Validation accuracy at 0.6469998359680176
# Epoch 25, CIFAR-10 Batch 3:  Loss at 0.001961829373613
# Validation accuracy at 0.6413998603820801
# Epoch 25, CIFAR-10 Batch 4:  Loss at 0.000802055059466511
# Validation accuracy at 0.6499999165534973
# Epoch 25, CIFAR-10 Batch 5:  Loss at 0.001812695525586605
# Validation accuracy at 0.6401998996734619
# Epoch 26, CIFAR-10 Batch 1:  Loss at 0.0009410073980689049
# Validation accuracy at 0.6377999186515808
# Epoch 26, CIFAR-10 Batch 2:  Loss at 0.000588241673540324
# Validation accuracy at 0.6393998861312866
# Epoch 26, CIFAR-10 Batch 3:  Loss at 0.001336198067292571
# Validation accuracy at 0.638999879360199
# Epoch 26, CIFAR-10 Batch 4:  Loss at 0.0023947188165038824
# Validation accuracy at 0.6559998989105225
# Epoch 26, CIFAR-10 Batch 5:  Loss at 0.0012457341654226184
# Validation accuracy at 0.6337998509407043
# Epoch 27, CIFAR-10 Batch 1:  Loss at 0.0018860460259020329
# Validation accuracy at 0.6231999397277832
# Epoch 27, CIFAR-10 Batch 2:  Loss at 0.00044633401557803154
# Validation accuracy at 0.6481999158859253
# Epoch 27, CIFAR-10 Batch 3:  Loss at 0.0007942243246361613
# Validation accuracy at 0.6365999579429626
# Epoch 27, CIFAR-10 Batch 4:  Loss at 0.00036480659036897123
# Validation accuracy at 0.6421999335289001
# Epoch 27, CIFAR-10 Batch 5:  Loss at 0.000941316713578999
# Validation accuracy at 0.6441998481750488
# Epoch 28, CIFAR-10 Batch 1:  Loss at 0.0027958566788583994
# Validation accuracy at 0.6451998949050903
# Epoch 28, CIFAR-10 Batch 2:  Loss at 0.0004535798798315227
# Validation accuracy at 0.6441998481750488
# Epoch 28, CIFAR-10 Batch 3:  Loss at 0.0017782854847609997
# Validation accuracy at 0.6283999085426331
# Epoch 28, CIFAR-10 Batch 4:  Loss at 0.00032116236980073154
# Validation accuracy at 0.6423999071121216
# Epoch 28, CIFAR-10 Batch 5:  Loss at 0.0020763473585247993
# Validation accuracy at 0.632999837398529
# Epoch 29, CIFAR-10 Batch 1:  Loss at 0.002068371046334505
# Validation accuracy at 0.6377999186515808
# Epoch 29, CIFAR-10 Batch 2:  Loss at 0.0025267479941248894
# Validation accuracy at 0.6271998882293701
# Epoch 29, CIFAR-10 Batch 3:  Loss at 0.0016429777024313807
# Validation accuracy at 0.6365998983383179
# Epoch 29, CIFAR-10 Batch 4:  Loss at 0.00019877274462487549
# Validation accuracy at 0.6403998732566833
# Epoch 29, CIFAR-10 Batch 5:  Loss at 0.0025407630018889904
# Validation accuracy at 0.6343998908996582
# Epoch 30, CIFAR-10 Batch 1:  Loss at 0.0010018713073804975
# Validation accuracy at 0.6293998956680298
# Epoch 30, CIFAR-10 Batch 2:  Loss at 0.002205875003710389
# Validation accuracy at 0.6355999112129211
# Epoch 30, CIFAR-10 Batch 3:  Loss at 0.0009974522981792688
# Validation accuracy at 0.6485998630523682
# Epoch 30, CIFAR-10 Batch 4:  Loss at 0.0011822276283055544
# Validation accuracy at 0.6277998685836792
# Epoch 30, CIFAR-10 Batch 5:  Loss at 0.0003210670256521553
# Validation accuracy at 0.630599856376648
# Epoch 31, CIFAR-10 Batch 1:  Loss at 0.0011101430281996727
# Validation accuracy at 0.6351998448371887
# Epoch 31, CIFAR-10 Batch 2:  Loss at 0.0006847037002444267
# Validation accuracy at 0.63239985704422
# Epoch 31, CIFAR-10 Batch 3:  Loss at 0.001175611512735486
# Validation accuracy at 0.6431998610496521
# Epoch 31, CIFAR-10 Batch 4:  Loss at 0.000629462068900466
# Validation accuracy at 0.6411998867988586
# Epoch 31, CIFAR-10 Batch 5:  Loss at 0.00027806032449007034
# Validation accuracy at 0.6425999402999878
# Epoch 32, CIFAR-10 Batch 1:  Loss at 0.000640419777482748
# Validation accuracy at 0.6449998617172241
# Epoch 32, CIFAR-10 Batch 2:  Loss at 0.0013994319597259164
# Validation accuracy at 0.6431998610496521
# Epoch 32, CIFAR-10 Batch 3:  Loss at 0.002485360950231552
# Validation accuracy at 0.6349999308586121
# Epoch 32, CIFAR-10 Batch 4:  Loss at 0.0005140083376318216
# Validation accuracy at 0.6459998488426208
# Epoch 32, CIFAR-10 Batch 5:  Loss at 0.0001851031556725502
# Validation accuracy at 0.6359999179840088
# Epoch 33, CIFAR-10 Batch 1:  Loss at 0.0012641226639971137
# Validation accuracy at 0.6445998549461365
# Epoch 33, CIFAR-10 Batch 2:  Loss at 0.0011569878552109003
# Validation accuracy at 0.6297999024391174
# Epoch 33, CIFAR-10 Batch 3:  Loss at 0.00028076983289793134
# Validation accuracy at 0.6415998935699463
# Epoch 33, CIFAR-10 Batch 4:  Loss at 0.0006218015332706273
# Validation accuracy at 0.6373999118804932
# Epoch 33, CIFAR-10 Batch 5:  Loss at 0.001287910621613264
# Validation accuracy at 0.6343998908996582
# Epoch 34, CIFAR-10 Batch 1:  Loss at 0.00042598822619765997
# Validation accuracy at 0.6253998875617981
# Epoch 34, CIFAR-10 Batch 2:  Loss at 0.00021895841928198934
# Validation accuracy at 0.6271998882293701
# Epoch 34, CIFAR-10 Batch 3:  Loss at 0.0004954483592882752
# Validation accuracy at 0.6349998712539673
# Epoch 34, CIFAR-10 Batch 4:  Loss at 0.00022004576749168336
# Validation accuracy at 0.6347999572753906
# Epoch 34, CIFAR-10 Batch 5:  Loss at 0.0004940676735714078
# Validation accuracy at 0.6335999369621277
# Epoch 35, CIFAR-10 Batch 1:  Loss at 0.0007104540709406137
# Validation accuracy at 0.6385999321937561
# Epoch 35, CIFAR-10 Batch 2:  Loss at 0.0011442835675552487
# Validation accuracy at 0.625999927520752
# Epoch 35, CIFAR-10 Batch 3:  Loss at 0.0009516627178527415
# Validation accuracy at 0.6381999254226685
# Epoch 35, CIFAR-10 Batch 4:  Loss at 0.00030447921017184854
# Validation accuracy at 0.6405998468399048
# Epoch 35, CIFAR-10 Batch 5:  Loss at 0.0006284888368099928
# Validation accuracy at 0.6449999213218689
# Epoch 36, CIFAR-10 Batch 1:  Loss at 0.001700753578916192
# Validation accuracy at 0.6227999329566956
# Epoch 36, CIFAR-10 Batch 2:  Loss at 0.0011597491102293134
# Validation accuracy at 0.6327998638153076
# Epoch 36, CIFAR-10 Batch 3:  Loss at 0.0012454896932467818
# Validation accuracy at 0.6381999254226685
# Epoch 36, CIFAR-10 Batch 4:  Loss at 0.00055456388508901
# Validation accuracy at 0.6243999004364014
# Epoch 36, CIFAR-10 Batch 5:  Loss at 0.0012484743492677808
# Validation accuracy at 0.6425999402999878
# Epoch 37, CIFAR-10 Batch 1:  Loss at 0.00014732698036823422
# Validation accuracy at 0.6253999471664429
# Epoch 37, CIFAR-10 Batch 2:  Loss at 0.003429679898545146
# Validation accuracy at 0.6019998788833618
# Epoch 37, CIFAR-10 Batch 3:  Loss at 0.00013804470654577017
# Validation accuracy at 0.627599835395813
# Epoch 37, CIFAR-10 Batch 4:  Loss at 0.0009126417571678758
# Validation accuracy at 0.631399929523468
# Epoch 37, CIFAR-10 Batch 5:  Loss at 0.0012933076359331608
# Validation accuracy at 0.6253998875617981
# Epoch 38, CIFAR-10 Batch 1:  Loss at 0.002576531143859029
# Validation accuracy at 0.6385999321937561
# Epoch 38, CIFAR-10 Batch 2:  Loss at 0.0019554481841623783
# Validation accuracy at 0.6385999321937561
# Epoch 38, CIFAR-10 Batch 3:  Loss at 0.00042555396794341505
# Validation accuracy at 0.6363998651504517
# Epoch 38, CIFAR-10 Batch 4:  Loss at 0.0014661280438303947
# Validation accuracy at 0.6323999166488647
# Epoch 38, CIFAR-10 Batch 5:  Loss at 0.0011276734294369817
# Validation accuracy at 0.6419999003410339
# Epoch 39, CIFAR-10 Batch 1:  Loss at 0.0009438172564841807
# Validation accuracy at 0.6409998536109924
# Epoch 39, CIFAR-10 Batch 2:  Loss at 0.002425271552056074
# Validation accuracy at 0.6415998935699463
# Epoch 39, CIFAR-10 Batch 3:  Loss at 0.0008157965494319797
# Validation accuracy at 0.6465998888015747
# Epoch 39, CIFAR-10 Batch 4:  Loss at 5.9616402722895145e-05
# Validation accuracy at 0.6361998915672302
# Epoch 39, CIFAR-10 Batch 5:  Loss at 0.0012674815952777863
# Validation accuracy at 0.6471998691558838
# Epoch 40, CIFAR-10 Batch 1:  Loss at 0.0004242051509208977
# Validation accuracy at 0.6417999267578125
# Epoch 40, CIFAR-10 Batch 2:  Loss at 0.00021376948279794306
# Validation accuracy at 0.6449999213218689
# Epoch 40, CIFAR-10 Batch 3:  Loss at 0.0011842957464978099
# Validation accuracy at 0.6485999226570129
# Epoch 40, CIFAR-10 Batch 4:  Loss at 0.0005699241883121431
# Validation accuracy at 0.6389999389648438
# Epoch 40, CIFAR-10 Batch 5:  Loss at 0.0009105488425120711
# Validation accuracy at 0.6463999152183533
# Epoch 41, CIFAR-10 Batch 1:  Loss at 0.0001090439036488533
# Validation accuracy at 0.6349998712539673
# Epoch 41, CIFAR-10 Batch 2:  Loss at 7.584603008581325e-05
# Validation accuracy at 0.6387998461723328
# Epoch 41, CIFAR-10 Batch 3:  Loss at 5.590009823208675e-05
# Validation accuracy at 0.6471999287605286
# Epoch 41, CIFAR-10 Batch 4:  Loss at 0.0004726857878267765
# Validation accuracy at 0.6321998834609985
# Epoch 41, CIFAR-10 Batch 5:  Loss at 7.002663187449798e-05
# Validation accuracy at 0.6355998516082764
# Epoch 42, CIFAR-10 Batch 1:  Loss at 0.0016715741949155927
# Validation accuracy at 0.6205999851226807
# Epoch 42, CIFAR-10 Batch 2:  Loss at 0.00035451893927529454
# Validation accuracy at 0.624799907207489
# Epoch 42, CIFAR-10 Batch 3:  Loss at 0.0001691474171821028
# Validation accuracy at 0.6203998923301697
# Epoch 42, CIFAR-10 Batch 4:  Loss at 0.00019174440240021795
# Validation accuracy at 0.6257999539375305
# Epoch 42, CIFAR-10 Batch 5:  Loss at 0.0003868789644911885
# Validation accuracy at 0.6383998394012451
# Epoch 43, CIFAR-10 Batch 1:  Loss at 0.000461423653177917
# Validation accuracy at 0.6407999396324158
# Epoch 43, CIFAR-10 Batch 2:  Loss at 0.0011369369458407164
# Validation accuracy at 0.6375998854637146
# Epoch 43, CIFAR-10 Batch 3:  Loss at 0.000551755481865257
# Validation accuracy at 0.6357998847961426
# Epoch 43, CIFAR-10 Batch 4:  Loss at 0.00021659857884515077
# Validation accuracy at 0.642599880695343
# Epoch 43, CIFAR-10 Batch 5:  Loss at 0.0001902087969938293
# Validation accuracy at 0.6529998183250427
# Epoch 44, CIFAR-10 Batch 1:  Loss at 0.00136865908280015
# Validation accuracy at 0.6509998440742493
# Epoch 44, CIFAR-10 Batch 2:  Loss at 0.0004117491189390421
# Validation accuracy at 0.6263999342918396
# Epoch 44, CIFAR-10 Batch 3:  Loss at 0.00020330888219177723
# Validation accuracy at 0.6441999077796936
# Epoch 44, CIFAR-10 Batch 4:  Loss at 0.0009236257756128907
# Validation accuracy at 0.6361998319625854
# Epoch 44, CIFAR-10 Batch 5:  Loss at 0.0003739162057172507
# Validation accuracy at 0.6379998922348022
# Epoch 45, CIFAR-10 Batch 1:  Loss at 0.00015057192649692297
# Validation accuracy at 0.6391998529434204
# Epoch 45, CIFAR-10 Batch 2:  Loss at 0.0007668672478757799
# Validation accuracy at 0.6339999437332153
# Epoch 45, CIFAR-10 Batch 3:  Loss at 0.0009330990724265575
# Validation accuracy at 0.6357998847961426
# Epoch 45, CIFAR-10 Batch 4:  Loss at 0.0002716198214329779
# Validation accuracy at 0.6345999240875244
# Epoch 45, CIFAR-10 Batch 5:  Loss at 0.0006600181804969907
# Validation accuracy at 0.642599880695343
# Epoch 46, CIFAR-10 Batch 1:  Loss at 0.0007698278059251606
# Validation accuracy at 0.6469998955726624
# Epoch 46, CIFAR-10 Batch 2:  Loss at 0.0009358465322293341
# Validation accuracy at 0.630599856376648
# Epoch 46, CIFAR-10 Batch 3:  Loss at 0.00024828442838042974
# Validation accuracy at 0.6553998589515686
# Epoch 46, CIFAR-10 Batch 4:  Loss at 0.00022141073714010417
# Validation accuracy at 0.6419999003410339
# Epoch 46, CIFAR-10 Batch 5:  Loss at 0.0001842192723415792
# Validation accuracy at 0.645599901676178
# Epoch 47, CIFAR-10 Batch 1:  Loss at 8.484798308927566e-05
# Validation accuracy at 0.6441998481750488
# Epoch 47, CIFAR-10 Batch 2:  Loss at 0.00016161848907358944
# Validation accuracy at 0.6445999145507812
# Epoch 47, CIFAR-10 Batch 3:  Loss at 5.093997606309131e-05
# Validation accuracy at 0.6563999056816101
# Epoch 47, CIFAR-10 Batch 4:  Loss at 0.0007304963073693216
# Validation accuracy at 0.6295998692512512
# Epoch 47, CIFAR-10 Batch 5:  Loss at 0.0008018166408874094
# Validation accuracy at 0.6469998359680176
# Epoch 48, CIFAR-10 Batch 1:  Loss at 0.00035256583942100406
# Validation accuracy at 0.6413999199867249
# Epoch 48, CIFAR-10 Batch 2:  Loss at 0.0004497864574659616
# Validation accuracy at 0.6421999335289001
# Epoch 48, CIFAR-10 Batch 3:  Loss at 5.2795126975979656e-05
# Validation accuracy at 0.6499998569488525
# Epoch 48, CIFAR-10 Batch 4:  Loss at 8.409604924963787e-05
# Validation accuracy at 0.6453999280929565
# Epoch 48, CIFAR-10 Batch 5:  Loss at 0.0002340665232622996
# Validation accuracy at 0.6445999145507812
# Epoch 49, CIFAR-10 Batch 1:  Loss at 9.495959966443479e-05
# Validation accuracy at 0.6459999084472656
# Epoch 49, CIFAR-10 Batch 2:  Loss at 0.0003475220000836998
# Validation accuracy at 0.6395999193191528
# Epoch 49, CIFAR-10 Batch 3:  Loss at 0.00027723482344299555
# Validation accuracy at 0.6355999112129211
# Epoch 49, CIFAR-10 Batch 4:  Loss at 0.0003978349268436432
# Validation accuracy at 0.6231999397277832
# Epoch 49, CIFAR-10 Batch 5:  Loss at 0.001739640487357974
# Validation accuracy at 0.6233998537063599
# Epoch 50, CIFAR-10 Batch 1:  Loss at 0.00022913762950338423
# Validation accuracy at 0.634199857711792
# Epoch 50, CIFAR-10 Batch 2:  Loss at 0.0005954845692031085
# Validation accuracy at 0.6195998787879944
# Epoch 50, CIFAR-10 Batch 3:  Loss at 2.859825690393336e-05
# Validation accuracy at 0.6279999017715454
# Epoch 50, CIFAR-10 Batch 4:  Loss at 9.68344829743728e-05
# Validation accuracy at 0.627799928188324
# Epoch 50, CIFAR-10 Batch 5:  Loss at 0.00026544928550720215
# Validation accuracy at 0.6345998644828796

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

# save_model_path = './image_classification'
save_model_path = '/dev/tf_models/image_classification'

n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6313291139240507

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
